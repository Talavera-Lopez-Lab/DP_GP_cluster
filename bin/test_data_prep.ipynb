# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/unstim_WT_counts_df.txt', sep='.\t', index_col=0, engine='python')
df = (
    df
    .fillna(0)
    .loc[(df != 0).all(axis=1)]
    .sample(n=1000, random_state=1776)
)
df
# Out:
#             WT_no1_unstim_6h_quan  WT_no2_unstim_6h_quan  \
# GeneNam
# Rsbn1l-20                     7.0                    9.0
# Ocstamp-20                    1.0                    2.0
# Mrpl13-20                    18.0                   11.0
# Pi4ka-20                      0.0                    0.0
# Fbxl3-20                    159.0                  255.0
# ...                           ...                    ...
# Phf20-20                     56.0                   53.0
# Or5b21-20                     0.0                    0.0
# Llgl2-20                      5.0                    7.0
# Cryzl2-20                     8.0                    8.0
# Actl7b-20                     1.0                    0.0
#
#             WT_no3_unstim_6h_quant
# GeneNam
# Rsbn1l-20                       76
# Ocstamp-20                       2
# Mrpl13-20                      205
# Pi4ka-20                         9
# Fbxl3-20                      2022
# ...                            ...
# Phf20-20                       535
# Or5b21-20                        3
# Llgl2-20                        69
# Cryzl2-20                       75
# Actl7b-20                       11
#
# [1000 rows x 3 columns]

# %%
df.to_csv('../../data/unstim_WT_counts_df_sample.txt', sep='\t')
